# %% [markdown]
# <a href="https://colab.research.google.com/github/akhil262019/akhil262019/blob/main/Covid19_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing libraries
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df=pd.read_json('https://www.mohfw.gov.in/data/datanew.json')
df
# Out:
#     sno                                state_name  active  positive     cured  \
# 0     1               Andaman and Nicobar Islands      59     10340     10152
# 1     2                            Andhra Pradesh    2714   2327662   2310215
# 2     3                         Arunachal Pradesh     257     65034     64481
# 3     4                                     Assam    4858    731662    718798
# 4     5                                     Bihar    2377    839591    824942
# 5     6                                Chandigarh     529     95046     93352
# 6     7                              Chhattisgarh    3043   1159921   1142831
# 7     8  Dadra and Nagar Haveli and Daman and Diu       9     11512     11499
# 8     9                                     Delhi    2040   1944978   1916642
# 9    10                                       Goa     721    250862    246295
# 10   11                                   Gujarat    4896   1244114   1228264
# ...

# %%
df.shape
# Out:
# (37, 13)

# %%
df.isnull().sum()
# Out:
# sno                 0
# state_name          0
# active              0
# positive            0
# cured               0
# death               0
# new_active          0
# new_positive        0
# new_cured           0
# new_death           0
# death_reconsille    0
# total               0
# state_code          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sno               37 non-null     int64
#  1   state_name        37 non-null     object
#  2   active            37 non-null     int64
#  3   positive          37 non-null     int64
#  4   cured             37 non-null     int64
#  5   death             37 non-null     int64
#  6   new_active        37 non-null     int64
#  7   new_positive      37 non-null     int64
#  8   new_cured         37 non-null     int64
#  9   new_death         37 non-null     int64
#  10  death_reconsille  37 non-null     object
#  11  total             37 non-null     object
#  12  state_code        37 non-null     int64
# dtypes: int64(10), object(3)
# memory usage: 3.9+ KB

# %%
df.describe()
# Out:
#              sno         active      positive         cured          death  \
# count  37.000000      37.000000  3.700000e+01  3.700000e+01      37.000000
# mean   19.000000    7873.189189  2.367763e+06  2.331467e+06   28423.378378
# std    10.824355   24155.424434  7.223652e+06  7.112300e+06   88169.111169
# min     1.000000       0.000000  1.034000e+04  1.015200e+04       4.000000
# 25%    10.000000     689.000000  1.032700e+05  1.004400e+05    1165.000000
# 50%    19.000000    1906.000000  7.316620e+05  7.187980e+05    7702.000000
# 75%    28.000000    4511.000000  1.300873e+06  1.286111e+06   14733.000000
# max    37.000000  145654.000000  4.380362e+07  4.313214e+07  525825.000000
#
#           new_active  new_positive     new_cured      new_death  state_code
# count      37.000000  3.700000e+01  3.700000e+01      37.000000   37.000000
# mean     8047.621622  2.368929e+06  2.332456e+06   28425.405405   18.324324
# ...

# %%
df.columns
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
df.keys()
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
df.nunique()
# Out:
# sno                 37
# state_name          37
# active              37
# positive            37
# cured               37
# death               37
# new_active          37
# new_positive        37
# new_cured           37
# new_death           37
# death_reconsille     2
# total                7
# state_code          37
# dtype: int64

# %%
df.tail()
# Out:
#     sno     state_name  active  positive     cured   death  new_active  \
# 32   33        Tripura    1906    103270    100440     924        2070
# 33   34    Uttarakhand    1185    440063    431176    7702        1272
# 34   35  Uttar Pradesh    2529   2097156   2071073   23554        2589
# 35   36    West Bengal   28969   2074550   2024293   21288       28399
# 36   37                 145654  43803619  43132140  525825      148881
#
#     new_positive  new_cured  new_death death_reconsille total  state_code
# 32        103652     100658        924                                 16
# 33        440252     431276       7704                      2           5
# 34       2097595    2071451      23555                      1           9
# 35       2077005    2027312      21294                      6          19
# 36      43825185   43150434     525870               15    45           0

# %%
df=df.iloc[:36]
df
# Out:
#     sno                                state_name  active  positive    cured  \
# 0     1               Andaman and Nicobar Islands      59     10340    10152
# 1     2                            Andhra Pradesh    2714   2327662  2310215
# 2     3                         Arunachal Pradesh     257     65034    64481
# 3     4                                     Assam    4858    731662   718798
# 4     5                                     Bihar    2377    839591   824942
# 5     6                                Chandigarh     529     95046    93352
# 6     7                              Chhattisgarh    3043   1159921  1142831
# 7     8  Dadra and Nagar Haveli and Daman and Diu       9     11512    11499
# 8     9                                     Delhi    2040   1944978  1916642
# 9    10                                       Goa     721    250862   246295
# 10   11                                   Gujarat    4896   1244114  1228264
# ...

# %%
df["active"].sum(axis=0)
# Out:
# 145654

# %%
df["positive"].sum(axis=0)
# Out:
# 43803619

# %%
df["cured"].sum(axis=0)
# Out:
# 43132140

# %%
df["death"].sum(axis=0)
# Out:
# 525840

# %%
df["new_active"].sum(axis=0)
# Out:
# 148881

# %%
df["new_positive"].sum(axis=0)
# Out:
# 43825185

# %%
df["new_cured"].sum(axis=0)
# Out:
# 43150434

# %%
df["new_death"].sum(axis=0)
# Out:
# 525870

# %% [markdown]
# **Data Visualization**

# %%
sn.pairplot(data=df)

# %%
case_df=df.sum()
case_df
# Out:
# sno                                                               666
# state_name          Andaman and Nicobar IslandsAndhra PradeshAruna...
# active                                                         145654
# positive                                                     43803619
# cured                                                        43132140
# death                                                          525840
# new_active                                                     148881
# new_positive                                                 43825185
# new_cured                                                    43150434
# new_death                                                      525870
# death_reconsille                                                   15
# total                                                 221111177121216
# state_code                                                        678
# dtype: object

# %%
case_df.drop(['sno','state_name','state_code'],inplace=True)
case_df
# Out:
# active                       145654
# positive                   43803619
# cured                      43132140
# death                        525840
# new_active                   148881
# new_positive               43825185
# new_cured                  43150434
# new_death                    525870
# death_reconsille                 15
# total               221111177121216
# dtype: object
